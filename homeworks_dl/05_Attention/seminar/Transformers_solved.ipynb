# %%
# !wget -O news.zip -qq --no-check-certificate "https://drive.google.com/uc?export=download&id=1hIVVpBqM6VU4n3ERkKq4tFaH4sKN0Hab"
# !unzip news.zip
# Out:
# Archive:  news.zip
#   inflating: news.csv

# %%
# !pip show torchtext
# !pip show sacremoses
# Out:
# Name: torchtext
# Version: 0.17.1
# Summary: Text utilities, models, transforms, and datasets for PyTorch.
# Home-page: https://github.com/pytorch/text
# Author: PyTorch Text Team
# Author-email: packages@pytorch.org
# License: BSD
# Location: /Users/nikolayborovets/Desktop/FALT_MIPT/ML/ml_mipt_dafe/.venv/lib/python3.11/site-packages
# Requires: numpy, requests, torch, torchdata, tqdm
# Required-by:
# WARNING: Package(s) not found: sacremoses

# %%
# !pip uninstall -y torchtext
# !pip install torchtext==0.6.0
# !pip install sacremoses==0.0.5
# !pip install matplotlib
# Out:
# Requirement already satisfied: torchtext==0.6.0 in /Users/nikolayborovets/Desktop/FALT_MIPT/ML/ml_mipt_dafe/.venv/lib/python3.11/site-packages (0.6.0)
# Requirement already satisfied: tqdm in /Users/nikolayborovets/Desktop/FALT_MIPT/ML/ml_mipt_dafe/.venv/lib/python3.11/site-packages (from torchtext==0.6.0) (4.67.1)
# Requirement already satisfied: requests in /Users/nikolayborovets/Desktop/FALT_MIPT/ML/ml_mipt_dafe/.venv/lib/python3.11/site-packages (from torchtext==0.6.0) (2.32.3)
# Requirement already satisfied: torch in /Users/nikolayborovets/Desktop/FALT_MIPT/ML/ml_mipt_dafe/.venv/lib/python3.11/site-packages (from torchtext==0.6.0) (2.2.1)
# Requirement already satisfied: numpy in /Users/nikolayborovets/Desktop/FALT_MIPT/ML/ml_mipt_dafe/.venv/lib/python3.11/site-packages (from torchtext==0.6.0) (1.26.4)
# Requirement already satisfied: six in /Users/nikolayborovets/Desktop/FALT_MIPT/ML/ml_mipt_dafe/.venv/lib/python3.11/site-packages (from torchtext==0.6.0) (1.17.0)
# Requirement already satisfied: sentencepiece in /Users/nikolayborovets/Desktop/FALT_MIPT/ML/ml_mipt_dafe/.venv/lib/python3.11/site-packages (from torchtext==0.6.0) (0.2.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/nikolayborovets/Desktop/FALT_MIPT/ML/ml_mipt_dafe/.venv/lib/python3.11/site-packages (from requests->torchtext==0.6.0) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/nikolayborovets/Desktop/FALT_MIPT/ML/ml_mipt_dafe/.venv/lib/python3.11/site-packages (from requests->torchtext==0.6.0) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/nikolayborovets/Desktop/FALT_MIPT/ML/ml_mipt_dafe/.venv/lib/python3.11/site-packages (from requests->torchtext==0.6.0) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/nikolayborovets/Desktop/FALT_MIPT/ML/ml_mipt_dafe/.venv/lib/python3.11/site-packages (from requests->torchtext==0.6.0) (2025.4.26)
# Requirement already satisfied: filelock in /Users/nikolayborovets/Desktop/FALT_MIPT/ML/ml_mipt_dafe/.venv/lib/python3.11/site-packages (from torch->torchtext==0.6.0) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /Users/nikolayborovets/Desktop/FALT_MIPT/ML/ml_mipt_dafe/.venv/lib/python3.11/site-packages (from torch->torchtext==0.6.0) (4.13.2)
# Requirement already satisfied: sympy in /Users/nikolayborovets/Desktop/FALT_MIPT/ML/ml_mipt_dafe/.venv/lib/python3.11/site-packages (from torch->torchtext==0.6.0) (1.14.0)
# Requirement already satisfied: networkx in /Users/nikolayborovets/Desktop/FALT_MIPT/ML/ml_mipt_dafe/.venv/lib/python3.11/site-packages (from torch->torchtext==0.6.0) (3.5)
# Requirement already satisfied: jinja2 in /Users/nikolayborovets/Desktop/FALT_MIPT/ML/ml_mipt_dafe/.venv/lib/python3.11/site-packages (from torch->torchtext==0.6.0) (3.1.6)
# Requirement already satisfied: fsspec in /Users/nikolayborovets/Desktop/FALT_MIPT/ML/ml_mipt_dafe/.venv/lib/python3.11/site-packages (from torch->torchtext==0.6.0) (2025.5.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/nikolayborovets/Desktop/FALT_MIPT/ML/ml_mipt_dafe/.venv/lib/python3.11/site-packages (from jinja2->torch->torchtext==0.6.0) (3.0.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/nikolayborovets/Desktop/FALT_MIPT/ML/ml_mipt_dafe/.venv/lib/python3.11/site-packages (from sympy->torch->torchtext==0.6.0) (1.3.0)
#
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: pip install --upgrade pip

# %%
# !pip show torchtext
# Out:
# Name: torchtext
# Version: 0.6.0
# Summary: Text utilities and datasets for PyTorch
# Home-page: https://github.com/pytorch/text
# Author: PyTorch core devs and James Bradbury
# Author-email: jekbradbury@gmail.com
# License: BSD
# Location: /Users/nikolayborovets/Desktop/FALT_MIPT/ML/ml_mipt_dafe/.venv/lib/python3.11/site-packages
# Requires: numpy, requests, sentencepiece, six, torch, tqdm
# Required-by:

# %%
import numpy as np

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.autograd import Variable

import matplotlib.pyplot as plt
# %matplotlib inline


DEVICE = torch.device('mps') # Use 'mps' for Apple Silicon Macs, 'cuda' for NVIDIA GPUs, or 'cpu' otherwise

# if torch.cuda.is_available():
#     from torch.cuda import FloatTensor, LongTensor
#     DEVICE = torch.device('cuda')
# else:
#     from torch import FloatTensor, LongTensor
#     DEVICE = torch.device('cpu')

np.random.seed(42)

# %% [markdown]
# # Abstactive Summarization

# %% [markdown]
# Задача - по тексту сгенерировать выдержку из него.
#
# Например, попробуем по новостям генерировать заголовки:

# %%
# !shuf -n 10 news.csv
# Out:
# zsh:1: command not found: shuf

# %% [markdown]
# Токенизируем их. Будем использовать единый словарь для текста и заголовков.

# %%
from torchtext.data import Field, Example, Dataset, BucketIterator

BOS_TOKEN = '<s>'
EOS_TOKEN = '</s>'

word_field = Field(tokenize='moses', init_token=BOS_TOKEN, eos_token=EOS_TOKEN, lower=True)
fields = [('source', word_field), ('target', word_field)]

# %%
import pandas as pd
from tqdm.auto import tqdm

data = pd.read_csv('news.csv', delimiter=',')

examples = []
for _, row in tqdm(data.iterrows(), total=len(data)):
    source_text = word_field.preprocess(row.text)
    target_text = word_field.preprocess(row.title)
    examples.append(Example.fromlist([source_text, target_text], fields))
# Out:
#   0%|          | 0/74278 [00:00<?, ?it/s]

# %%
examples[0].source, examples[0].target
# Out:
# (['президент',
#   'украины',
#   'петр',
#   'порошенко',
#   'поздравил',
#   'боксера',
#   'александра',
#   'усика',
#   'с',
#   'победой',
#   'в',
#   'бою',
#   'против',
#   'россиянина',
#   'мурата',
#   'гассиева',
#   '.',
#   'об',
#   'этом',
#   'он',
#   'написал',
#   'в',
#   'своем',
#   'twitter',
#   '.',
#   '«',
#   'ни',
#   'секунды',
#   'не',
#   'сомневался',
#   ',',
#   'что',
#   'саша',
#   'победит',
#   '!',
#   'украинский',
#   'гимн',
#   ',',
#   'который',
#   'прозвучал',
#   'сегодня',
#   'в',
#   'москве',
#   'на',
#   'весь',
#   'мир',
#   ',',
#   '—',
#   'это',
#   'символ',
#   'нашей',
#   'борьбы',
#   ',',
#   'приближение',
#   'нашей',
#   'победы',
#   '.',
#   'украина',
#   'гордится',
#   'тобой',
#   '!',
#   'поздравляю',
#   'с',
#   'победой',
#   ',',
#   'чемпион',
#   '!',
#   '»',
#   ',',
#   '—',
#   'написал',
#   'он',
#   'сразу',
#   'после',
#   'объявления',
#   'решений',
#   'судей',
#   '.',
#   'ранее',
#   '22',
#   'июля',
#   'усик',
#   'единогласным',
#   'решением',
#   'судей',
#   'выиграл',
#   'поединок',
#   'из',
#   '12',
#   'раундов',
#   '.',
#   'украинец',
#   'стал',
#   'победителем',
#   'всемирной',
#   'боксерской',
#   'суперсерии',
#   ',',
#   'а',
#   'также',
#   'обладателем',
#   'четырех',
#   'чемпионских',
#   'поясов',
#   'по',
#   'версиям',
#   'международной',
#   'боксерской',
#   'федерации',
#   '(',
#   'ibf',
#   ')',
#   'и',
#   'всемирной',
#   'боксерской',
#   'ассоциации',
#   '(',
#   'wba',
#   ')',
#   ',',
#   'всемирной',
#   'боксерской',
#   'организации',
#   '(',
#   'wbo',
#   ')',
#   'и',
#   'всемирного',
#   'боксерского',
#   'совета',
#   '(',
#   'wbc',
#   ')',
#   '.'],
#  ['порошенко', 'назвал', 'боксера', 'усика', 'символом', 'борьбы', 'украины'])

# %% [markdown]
# Построим датасеты:

# %%
dataset = Dataset(examples, fields)

train_dataset, test_dataset = dataset.split(split_ratio=0.85)

print('Train size =', len(train_dataset))
print('Test size =', len(test_dataset))

word_field.build_vocab(train_dataset, min_freq=7)
print('Vocab size =', len(word_field.vocab))

train_iter, test_iter = BucketIterator.splits(
    datasets=(train_dataset, test_dataset), batch_sizes=(16, 32), shuffle=True, device=DEVICE, sort=False
)
# Out:
# Train size = 63136
# Test size = 11142
# Vocab size = 55806

# %% [markdown]
# ## Seq2seq for Abstractive Summarization
#
# Вообще задача не сильно отличается от машинного перевода:
#
# ![](https://image.ibb.co/jAf3S0/2018-11-20-9-42-17.png)
# *From [Get To The Point: Summarization with Pointer-Generator Networks](https://arxiv.org/pdf/1704.04368.pdf)*
#
# Тут на каждом шаге декодер подглядывает на все токены - точнее, их эмбеддинги после BiRNN.
#
# Возникает вопрос - а зачем вообще RNN, если потом все равно будем смотреть на всё.

# %% [markdown]
# # Transformer
#
# Из этой идеи - отказ от RNN - и получился Transformer.
#
# ![](https://hsto.org/webt/59/f0/44/59f04410c0e56192990801.png)
# *From Attention is all you need*
#
# Как в случае с RNN мы на каждом шаге применяем одну и ту же операцию (ячейку LSTM) к текущему входу, так и здесь - только теперь связей между timestamp'ами нет и можно обрабатывать их почти параллельно.
#
# *Код дальше очень сильно опирается на шикарную статью [The Annotated Transformer](http://nlp.seas.harvard.edu/2018/04/03/attention.html).*

# %% [markdown]
# ## Encoder
#
# Начнем с энкодера:
#
# ![](http://jalammar.github.io/images/t/transformer_resideual_layer_norm.png)
# *From [Illustrated Transformer](http://jalammar.github.io/illustrated-transformer/)*
#
# Он представляет из себя последовательность одинаковых блоков с self-attention + полносвязными слоями.
#
# Можно представить, что это - ячейка LSTM: она тоже применяется к каждому входу с одинаковыми весами. Разница основная в отсутствии рекуррентных связей: за счет этого энкодер может применяться одновременно ко всем входам батча.

# %% [markdown]
# ### Positional Encoding
#
# Нужно как-то кодировать информацию о том, в каком месте в предложении стоит токен. Авторы предложили делать так:
# $$PE_{(pos,2i)} = sin(pos / 10000^{2i/d_{\text{model}}})$$
# $$PE_{(pos,2i+1)} = cos(pos / 10000^{2i/d_{\text{model}}})$$
#
# где $(pos, i)$ - позиция в предложении и индекс в скрытом векторе размерности до $d_{model}$.

# %%
import math

class PositionalEncoding(nn.Module):
    def __init__(self, d_model, dropout, max_len=5000):
        super().__init__()
        self.dropout = nn.Dropout(p=dropout)

        pe = torch.zeros(max_len, d_model)
        position = torch.arange(0, max_len, dtype=torch.float).unsqueeze(1)
        div_term = torch.exp(torch.arange(0, d_model, 2, dtype=torch.float) * (-math.log(10000.0) / d_model))
        pe[:, 0::2] = torch.sin(position * div_term)
        pe[:, 1::2] = torch.cos(position * div_term)
        pe = pe.unsqueeze(0)
        self.register_buffer('pe', pe)

    def forward(self, x):
        x = x + self.pe[:, :x.size(1)]
        return self.dropout(x)

# %%
plt.figure(figsize=(15, 5))
pe = PositionalEncoding(20, 0)
y = pe(torch.zeros(1, 100, 20))
plt.plot(np.arange(100), y[0, :, 4:8].data.numpy())
plt.legend(["dim %d"%p for p in [4,5,6,7]])

# %% [markdown]
# В итоге эмбеддинги токена получается как сумма обычного эмбеддинга и эмбеддинга позиции:
# ![](http://jalammar.github.io/images/t/transformer_positional_encoding_vectors.png)
# *From [Illustrated Transformer](http://jalammar.github.io/illustrated-transformer/)*

# %% [markdown]
# ### Residual Connection
#
# Разберем блок энкодера - повторяющейся N раз комбинации операций на первом рисунке.
#
# Самое простое здесь - residual connection. Вместо к выходу произвольной функции $F$ прибавляется её вход
# $$y = F(x) \quad \to \quad y = F(x) + x$$
#
# Идея в том, что обычные сети сложно делать слишком глубокими - градиенты затухают. А через этот residual вход $x$ градиентам течь ничего не стоит. В итоге в картинках благодаря таким блокам получилось настакать дофига слоев и улучшить качество (см. ResNet).
#
# Ничего не мешает нам поступить также.

# %%
class ResidualBlock(nn.Module):
    def __init__(self, size, dropout_rate):
        super().__init__()
        self._norm = LayerNorm(size)
        self._dropout = nn.Dropout(dropout_rate)

    def forward(self, inputs, sublayer):
        return inputs + self._dropout(sublayer(self._norm(inputs)))

# %% [markdown]
# ### Layer Norm
#
# Дополнительно применяется нормализация LayerNorm.
#
# **Batch normalization**
# Мы вообще не разбирали, но BatchNorm работает так:
# $$\mu_j = \frac{1}{m}\sum_{i=1}^{m}x_{ij} \\    \sigma_j^2 = \frac{1}{m}\sum_{i=1}^{m}(x_{ij} - \mu_j)^2 \\    \hat{x}_{ij} = \frac{x_{ij} - \mu_j}{\sqrt{\sigma_j^2 + \epsilon}}$$
# $$y_{ij} = \gamma \ \hat{x}_{ij} + \beta$$
#
# На каждом батче эти $\mu$ и $\sigma$ пересчитываются, обновляя статистики. На инференсе используются накопленные статистики.
#
# Основной его недостаток - он плохо работает с рекуррентными сетями. Чтобы побороть это придумали:
#
# **Layer normalization**
# А сейчас мы будем пользоваться немного другими формулами:
# $$\mu_i = \frac{1}{m}\sum_{j=1}^{m}x_{ij} \\    \sigma_i^2 = \frac{1}{m}\sum_{j=1}^{m}(x_{ij} - \mu_i)^2 \\    \hat{x}_{ij} = \frac{x_{ij} - \mu_i}{\sqrt{\sigma_i^2 + \epsilon}}$$
# $$y_{ij} = \gamma \ \hat{x}_{ij} + \beta$$
#
# Разницу с ходу не видно, но она есть:
# ![](https://image.ibb.co/hjtuX0/layernorm.png)
# *From [Weight Normalization and Layer Normalization Explained ](http://mlexplained.com/2018/01/13/weight-normalization-and-layer-normalization-explained-normalization-in-deep-learning-part-2/)*
#
# Если в BatchNorm статистики считаются для каждой фичи усреднением по батчу, то теперь - для каждого входа усредением по фичам.

# %%
class LayerNorm(nn.Module):
    def __init__(self, features, eps=1e-6):
        super().__init__()

        self._gamma = nn.Parameter(torch.ones(features))
        self._beta = nn.Parameter(torch.zeros(features))
        self._eps = eps

    def forward(self, inputs):
        mean = inputs.mean(-1, keepdim=True)
        std = inputs.std(-1, keepdim=True)
        return self._gamma * (inputs - mean) / (std + self._eps) + self._beta

# %% [markdown]
# ### Attention
#
# Весь Transformer опирается на идею self-attention. Выглядит это так:
#
# ![](http://jalammar.github.io/images/t/transformer_self-attention_visualization.png)
# *From [Tensor2Tensor Tutorial](https://colab.research.google.com/github/tensorflow/tensor2tensor/blob/master/tensor2tensor/notebooks/hello_t2t.ipynb)*
#
# Эмбеддинг слова *it* строится как комбинация всех эмбеддингов предложения.
#
# В статье придумали делать такой аттеншен:
#
# $$\mathrm{Attention}(Q, K, V) = \mathrm{softmax}\left(\frac{QK^T}{\sqrt{d_k}}\right)V$$
#
# Это примерно как dot-attention на прошлом занятии: запрос (**Q**uery) умножается на ключи (**K**ey) скалярно, затем берется софтмакс - получаются оценки того, насколько интересны разные таймстемпы из значений (**V**alue).
#
# Например, $\mathrm{emb}(\text{it}) = \mathrm{Attention}(\text{it}, \ldots\text{because it was too tired}, \ldots\text{because it was too tired})$.
#
# Только теперь ещё с параметром $\frac{1}{\sqrt{d_k}}$, где $d_k$ - это размерность ключа. Утверждается, это работает лучше при больших размерностях ключа $d_k$.

# %%
class ScaledDotProductAttention(nn.Module):
    def __init__(self, dropout_rate):
        super().__init__()

        self._dropout = nn.Dropout(dropout_rate)

    def forward(self, query, key, value, mask):
        d_k = query.size(-1)
        scores = torch.matmul(query, key.transpose(-2, -1)) / math.sqrt(d_k)
        if mask is not None:
            scores = scores.masked_fill(mask == 0, -1e9)
        p_attn = F.softmax(scores, dim=-1)
        p_attn = self._dropout(p_attn)

        return torch.matmul(p_attn, value), p_attn

# %% [markdown]
# ### Multi-Head Attention
#
# ![](https://hsto.org/webt/59/f0/44/59f0440f1109b864893781.png)
#
# Важная идея, почему attention (и, главное, self-attention) заработал - использование нескольких голов (multi-head).
#
# Вообще, когда мы делаем attention - мы определяем похожесть ключа и запроса. Многоголовость помогает (должна) определять эту похожесть по разным критериям - синтаксически, семантически и т.д.
#
# Например, на картинке используется две головы и одна голова смотрит на *the animal* при генерации *it*, вторая - на *tired*:
#
# ![](http://jalammar.github.io/images/t/transformer_self-attention_visualization_2.png)
# *From [Tensor2Tensor Tutorial](https://colab.research.google.com/github/tensorflow/tensor2tensor/blob/master/tensor2tensor/notebooks/hello_t2t.ipynb)*
#
# Применяется это таким образом:
#
# $$\mathrm{MultiHead}(Q, K, V) = \mathrm{Concat}(\mathrm{head_1}, ...,
# \mathrm{head_h})W^O    \\
#     \mathrm{head_i} = \mathrm{Attention}(QW^Q_i, KW^K_i, VW^V_i)$$
#
# где $W^Q_i \in \mathbb{R}^{d_{model} \times d_k}, W_i^K \in \mathbb{R}^{d_{model} \times d_k}, W^V_i \in \mathbb{R}^{d_{model} \times d_v}, W^O \in \mathbb{R}^{hd_v \times d_{model}}$.
#
# В оригинальной статье использовали $h=8$, $d_k=d_v=d_{\text{model}}/h=64$.
#
# Процесс применения такой:
# ![](http://jalammar.github.io/images/t/transformer_multi-headed_self-attention-recap.png)
# *From Illustrated Transformer*

# %%
class MultiHeadedAttention(nn.Module):
    def __init__(self, heads_count, d_model, dropout_rate=0.1):
        super().__init__()

        assert d_model % heads_count == 0

        self._d_k = d_model // heads_count
        self._heads_count = heads_count
        self._attention = ScaledDotProductAttention(dropout_rate)
        self._attn_probs = None

        self._w_q = nn.Linear(d_model, d_model)
        self._w_k = nn.Linear(d_model, d_model)
        self._w_v = nn.Linear(d_model, d_model)
        self._w_o = nn.Linear(d_model, d_model)

    def forward(self, query, key, value, mask=None):
        if mask is not None:
            mask = mask.unsqueeze(1)
        nbatches = query.size(0)

        query = self._w_q(query).view(nbatches, -1, self._heads_count, self._d_k).transpose(1, 2)
        key = self._w_k(key).view(nbatches, -1, self._heads_count, self._d_k).transpose(1, 2)
        value = self._w_v(value).view(nbatches, -1, self._heads_count, self._d_k).transpose(1, 2)
        x, self._attn_probs = self._attention(query, key, value, mask)

        x = x.transpose(1, 2).contiguous().view(nbatches, -1, self._heads_count * self._d_k)
        x = self._w_o(x)
        return x

# %% [markdown]
# ### Position-wise Feed-Forward Networks
#
# Линейный блок в энкодере выглядит так:
# $$\mathrm{FFN}(x)=\max(0, xW_1 + b_1) W_2 + b_2$$

# %%
class PositionwiseFeedForward(nn.Module):
    def __init__(self, d_model, d_ff, dropout=0.1):
        super().__init__()

        self.w_1 = nn.Linear(d_model, d_ff)
        self.w_2 = nn.Linear(d_ff, d_model)
        self.dropout = nn.Dropout(dropout)

    def forward(self, inputs):
        return self.w_2(self.dropout(F.relu(self.w_1(inputs))))

# %% [markdown]
# ### Encoder block
#
# Соберем все в блок:

# %%
class EncoderBlock(nn.Module):
    def __init__(self, size, self_attn, feed_forward, dropout_rate):
        super().__init__()

        self._self_attn = self_attn
        self._feed_forward = feed_forward
        self._self_attention_block = ResidualBlock(size, dropout_rate)
        self._feed_forward_block = ResidualBlock(size, dropout_rate)

    def forward(self, inputs, mask):
        outputs = self._self_attention_block(inputs, lambda inputs: self._self_attn(inputs, inputs, inputs, mask))
        return self._feed_forward_block(outputs, self._feed_forward)

# %%
class Encoder(nn.Module):
    def __init__(self, vocab_size, d_model, d_ff, blocks_count, heads_count, dropout_rate):
        super().__init__()

        self._emb = nn.Sequential(
            nn.Embedding(vocab_size, d_model),
            PositionalEncoding(d_model, dropout_rate)
        )

        block = lambda: EncoderBlock(
            size=d_model,
            self_attn=MultiHeadedAttention(heads_count, d_model, dropout_rate),
            feed_forward=PositionwiseFeedForward(d_model, d_ff, dropout_rate),
            dropout_rate=dropout_rate
        )
        self._blocks = nn.ModuleList([block() for _ in range(blocks_count)])
        self._norm = LayerNorm(d_model)

    def forward(self, inputs, mask):
        inputs = self._emb(inputs)

        for block in self._blocks:
            inputs = block(inputs, mask)

        return self._norm(inputs)

# %% [markdown]
# ## Decoder
#
# ![](https://hsto.org/webt/59/f0/44/59f0440f7d88f805415140.png)
#
# Блок декодера (серая часть) состоит уже из трех частей:
# 1. Сперва - тот же self-attention, что и в энкодере
# 2. Затем - стандартный attention на выходы из энкодера + текущее состояние декодера (такой же был в seq2seq with attention)
# 3. Наконец - feed-forward блок
#
# Всё это, конечно, с residual связями.

# %%
class DecoderLayer(nn.Module):
    def __init__(self, size, self_attn, encoder_attn, feed_forward, dropout_rate):
        super().__init__()

        self._self_attn = self_attn
        self._encoder_attn = encoder_attn
        self._feed_forward = feed_forward
        self._self_attention_block = ResidualBlock(size, dropout_rate)
        self._attention_block = ResidualBlock(size, dropout_rate)
        self._feed_forward_block = ResidualBlock(size, dropout_rate)

    def forward(self, inputs, encoder_output, source_mask, target_mask):
        outputs = self._self_attention_block(
            inputs, lambda inputs: self._self_attn(inputs, inputs, inputs, target_mask)
        )
        outputs = self._attention_block(
            outputs, lambda inputs: self._encoder_attn(inputs, encoder_output, encoder_output, source_mask)
        )
        return self._feed_forward_block(outputs, self._feed_forward)

# %%
class Decoder(nn.Module):
    def __init__(self, vocab_size, d_model, d_ff, blocks_count, heads_count, dropout_rate):
        super().__init__()

        self._emb = nn.Sequential(
            nn.Embedding(vocab_size, d_model),
            PositionalEncoding(d_model, dropout_rate)
        )

        block = lambda: DecoderLayer(
            size=d_model,
            self_attn=MultiHeadedAttention(heads_count, d_model, dropout_rate),
            encoder_attn=MultiHeadedAttention(heads_count, d_model, dropout_rate),
            feed_forward=PositionwiseFeedForward(d_model, d_ff, dropout_rate),
            dropout_rate=dropout_rate
        )
        self._blocks = nn.ModuleList([block() for _ in range(blocks_count)])
        self._norm = LayerNorm(d_model)
        self._out_layer = nn.Linear(d_model, vocab_size)

    def forward(self, inputs, encoder_output, source_mask, target_mask):
        inputs = self._emb(inputs)
        for block in self._blocks:
            inputs = block(inputs, encoder_output, source_mask, target_mask)
        return self._out_layer(self._norm(inputs))

# %% [markdown]
# В декодере нужно аттентиться только на предыдущие токены - сгенерируем маску для этого:

# %%
def subsequent_mask(size):
    mask = torch.ones(size, size, device=DEVICE).triu_()
    return mask.unsqueeze(0) == 0

# %%
plt.figure(figsize=(5,5))
plt.imshow(subsequent_mask(20)[0].cpu().numpy())

# %% [markdown]
# ## Полная модель

# %%
class Generator(nn.Module):
    "Define standard linear + softmax generation step."
    def __init__(self, d_model, vocab):
        super(Generator, self).__init__()
        self.proj = nn.Linear(d_model, vocab)

    def forward(self, x):
        return F.log_softmax(self.proj(x), dim=-1)


class EncoderDecoder(nn.Module):
    """
    A standard Encoder-Decoder architecture. Base for this and many
    other models.
    """
    def __init__(self, source_vocab_size, target_vocab_size, d_model=256, d_ff=1024,
                 blocks_count=4, heads_count=8, dropout_rate=0.1):
        super(EncoderDecoder, self).__init__()

        self.d_model = d_model
        self.encoder = Encoder(source_vocab_size, d_model, d_ff, blocks_count, heads_count, dropout_rate)
        self.decoder = Decoder(target_vocab_size, d_model, d_ff, blocks_count, heads_count, dropout_rate)
        # self.generator = Generator(d_model, target_vocab_size)

        for p in self.parameters():
            if p.dim() > 1:
                nn.init.xavier_uniform_(p)

    def forward(self, source_inputs, target_inputs, source_mask, target_mask):
        encoder_output = self.encoder(source_inputs, source_mask)
        return self.decoder(target_inputs, encoder_output, source_mask, target_mask)

# %%
def make_mask(source_inputs, target_inputs, pad_idx):
    source_mask = (source_inputs != pad_idx).unsqueeze(-2)
    target_mask = (target_inputs != pad_idx).unsqueeze(-2)
    target_mask = target_mask & subsequent_mask(target_inputs.size(-1)).type_as(target_mask)
    return source_mask, target_mask


def convert_batch(batch, pad_idx=1):
    source_inputs, target_inputs = batch.source.transpose(0, 1), batch.target.transpose(0, 1)
    source_mask, target_mask = make_mask(source_inputs, target_inputs, pad_idx)

    return source_inputs, target_inputs, source_mask, target_mask

# %%
batch = next(iter(train_iter))

# %%
model = EncoderDecoder(source_vocab_size=len(word_field.vocab),
                  target_vocab_size=len(word_field.vocab)).to(DEVICE)

out = model(*convert_batch(batch))

# %%
out.shape, len(word_field.vocab)
# Out:
# (torch.Size([16, 17, 55806]), 55806)

# %% [markdown]
# ## Оптимизатор
#
# Тоже очень важно в данной модели - использовать правильный оптимизатор

# %%
class NoamOpt(object):
    def __init__(self, model_size, factor=2, warmup=4000, optimizer=None):
        if optimizer is not None:
            self.optimizer = optimizer
        else:
            self.optimizer = optim.Adam(model.parameters(), lr=0, betas=(0.9, 0.98), eps=1e-9)
        self._step = 0
        self.warmup = warmup
        self.factor = factor
        self.model_size = model_size
        self._rate = 0

    def step(self):
        self._step += 1
        rate = self.rate()
        for p in self.optimizer.param_groups:
            p['lr'] = rate
        self._rate = rate
        self.optimizer.step()

    def rate(self, step = None):
        if step is None:
            step = self._step
        return self.factor * (self.model_size ** (-0.5) * min(step ** (-0.5), step * self.warmup ** (-1.5)))

# %% [markdown]
# Идея в том, чтобы повышать learning rate в течении первых warmup шагов линейно, а затем понижать его по сложной формуле:
#
# $$
# lrate = d_{\text{model}}^{-0.5} \cdot
#   \min({step\_num}^{-0.5},
#     {step\_num} \cdot {warmup\_steps}^{-1.5})
# $$

# %%
opts = [NoamOpt(512, 1, 4000, None),
        NoamOpt(512, 1, 8000, None),
        NoamOpt(256, 1, 4000, None)]
plt.plot(np.arange(1, 20000), [[opt.rate(i) for opt in opts] for i in range(1, 20000)])
plt.legend(["512:4000", "512:8000", "256:4000"])

# %% [markdown]
# ## Тренировка модели

# %%
tqdm.get_lock().locks = []


def do_epoch(model, criterion, data_iter, optimizer=None, name=None):
    epoch_loss = 0

    is_train = not optimizer is None
    name = name or ''
    model.train(is_train)

    batches_count = len(data_iter)

    with torch.autograd.set_grad_enabled(is_train):
        with tqdm(total=batches_count) as progress_bar:
            for i, batch in enumerate(data_iter):
                source_inputs, target_inputs, source_mask, target_mask = convert_batch(batch)
                logits = model.forward(source_inputs, target_inputs[:, :-1], source_mask, target_mask[:, :-1, :-1])

                logits = logits.contiguous().view(-1, logits.shape[-1])
                target = target_inputs[:, 1:].contiguous().view(-1)
                loss = criterion(logits, target)

                epoch_loss += loss.item()

                if optimizer:
                    optimizer.optimizer.zero_grad()
                    loss.backward()
                    optimizer.step()

                progress_bar.update()
                progress_bar.set_description('{:>5s} Loss = {:.5f}, PPX = {:.2f}'.format(name, loss.item(),
                                                                                         math.exp(loss.item())))

            progress_bar.set_description('{:>5s} Loss = {:.5f}, PPX = {:.2f}'.format(
                name, epoch_loss / batches_count, math.exp(epoch_loss / batches_count))
            )
            progress_bar.refresh()

    return epoch_loss / batches_count


def fit(model, criterion, optimizer, train_iter, epochs_count=1, val_iter=None):
    best_val_loss = None
    for epoch in range(epochs_count):
        name_prefix = '[{} / {}] '.format(epoch + 1, epochs_count)
        train_loss = do_epoch(model, criterion, train_iter, optimizer, name_prefix + 'Train:')

        if not val_iter is None:
            val_loss = do_epoch(model, criterion, val_iter, None, name_prefix + '  Val:')

# %%
model = EncoderDecoder(source_vocab_size=len(word_field.vocab), target_vocab_size=len(word_field.vocab)).to(DEVICE)

pad_idx = word_field.vocab.stoi['<pad>']
criterion = nn.CrossEntropyLoss(ignore_index=pad_idx).to(DEVICE)

optimizer = NoamOpt(model.d_model)

fit(model, criterion, optimizer, train_iter, epochs_count=30, val_iter=test_iter)
# Out:
#   0%|          | 0/3946 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[65], line 8
#       4 criterion = nn.CrossEntropyLoss(ignore_index=pad_idx).to(DEVICE)
#       6 optimizer = NoamOpt(model.d_model)
# ----> 8 fit(model, criterion, optimizer, train_iter, epochs_count=30, val_iter=test_iter)
#
# Cell In[64], line 46, in fit(model, criterion, optimizer, train_iter, epochs_count, val_iter)
#      44 for epoch in range(epochs_count):
#      45     name_prefix = '[{} / {}] '.format(epoch + 1, epochs_count)
# ---> 46     train_loss = do_epoch(model, criterion, train_iter, optimizer, name_prefix + 'Train:')
#      48     if not val_iter is None:
#      49         val_loss = do_epoch(model, criterion, val_iter, None, name_prefix + '  Val:')
#
# Cell In[64], line 27, in do_epoch(model, criterion, data_iter, optimizer, name)
#      25 if optimizer:
#      26     optimizer.optimizer.zero_grad()
# ---> 27     loss.backward()
#      28     optimizer.step()
#      30 progress_bar.update()
#
# File ~/Desktop/FALT_MIPT/ML/ml_mipt_dafe/.venv/lib/python3.11/site-packages/torch/_tensor.py:522, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     512 if has_torch_function_unary(self):
#     513     return handle_torch_function(
#     514         Tensor.backward,
#     515         (self,),
#    (...)    520         inputs=inputs,
#     521     )
# --> 522 torch.autograd.backward(
#     523     self, gradient, retain_graph, create_graph, inputs=inputs
#     524 )
#
# File ~/Desktop/FALT_MIPT/ML/ml_mipt_dafe/.venv/lib/python3.11/site-packages/torch/autograd/__init__.py:266, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     261     retain_graph = create_graph
#     263 # The reason we repeat the same comment below is that
#     264 # some Python versions print out the first line of a multi-line function
#     265 # calls in the traceback and some print out the last line
# --> 266 Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     267     tensors,
#     268     grad_tensors_,
#     269     retain_graph,
#     270     create_graph,
#     271     inputs,
#     272     allow_unreachable=True,
#     273     accumulate_grad=True,
#     274 )
#
# KeyboardInterrupt:

# %%
# Сохранение обученной модели
MODEL_PATH = 'transformer_summarization_model.pt'  # Имя файла для сохранения

# Полное сохранение с дополнительной информацией
torch.save({
    'model_state_dict': model.state_dict(),
    'optimizer_state_dict': optimizer.optimizer.state_dict(),
    'vocab': word_field.vocab,
    'd_model': model.d_model,
    'heads_count': 8,
    'blocks_count': 4,
}, MODEL_PATH)

print(f"Модель успешно сохранена в {MODEL_PATH}")

# %% [markdown]
# ### Загрузка модели в будущем

# %%
def load_saved_model(model_path):
    checkpoint = torch.load(model_path, map_location=DEVICE)
    
    # Используем словарь из сохранённой модели
    saved_vocab = checkpoint['vocab']
    
    # Создаем модель с размером словаря из чекпоинта
    loaded_model = EncoderDecoder(
        source_vocab_size=len(saved_vocab),  # Используем сохранённый словарь
        target_vocab_size=len(saved_vocab),  # Используем сохранённый словарь
        d_model=checkpoint['d_model'],
        blocks_count=checkpoint['blocks_count'],
        heads_count=checkpoint['heads_count']
    ).to(DEVICE)
    
    # Загружаем веса
    loaded_model.load_state_dict(checkpoint['model_state_dict'])
    loaded_model.eval()
    
    print(f"Модель успешно загружена из {model_path}")
    
    # Также возвращаем словарь, чтобы использовать его при генерации
    return loaded_model, saved_vocab

# Загрузка модели и словаря
model_path = "transformer_summarization_model.pt"  # Путь к файлу с предобученной моделью
model, saved_vocab = load_saved_model(model_path)
# Out:
# Модель успешно загружена из transformer_summarization_model.pt

# %%
def generate_summary(model, saved_vocab, text, max_len=50, temperature=1.0, greedy=True):
    """
    Генерирует заголовок для заданного текста
    
    Args:
        model: загруженная модель Transformer
        saved_vocab: словарь, загруженный вместе с моделью
        text: исходный текст для суммаризации
        max_len: максимальная длина заголовка
        temperature: температура при семплировании (1.0 - нет изменений, <1.0 - более определенные результаты)
        greedy: если True, выбирается токен с максимальной вероятностью, иначе - семплирование
    
    Returns:
        str: сгенерированный заголовок
    """
    model.eval()
    
    # Предобработка текста с использованием сохраненного словаря
    # Используем метод tokenize функции moses из torchtext
    from sacremoses import MosesTokenizer
    mt = MosesTokenizer()
    tokens = mt.tokenize(text.lower())
    
    # Индексирование токенов с помощью сохраненного словаря
    indexed = []
    for t in tokens:
        if t in saved_vocab.stoi:
            indexed.append(saved_vocab.stoi[t])
        else:
            indexed.append(saved_vocab.stoi['<unk>'])
    
    # Создание тензоров входных данных
    source = torch.LongTensor([indexed]).to(DEVICE)
    source_mask = (source != saved_vocab.stoi['<pad>']).unsqueeze(-2)
    
    # Начальный токен для декодирования
    start_symbol = saved_vocab.stoi[BOS_TOKEN]
    
    # Инициализация с начальным токеном
    ys = torch.ones(1, 1).fill_(start_symbol).type_as(source).long().to(DEVICE)
    
    # Автореграссивное декодирование
    with torch.no_grad():
        encoder_output = model.encoder(source, source_mask)
        
        for i in range(max_len-1):
            # Создание маски для target последовательности
            target_mask = (ys != saved_vocab.stoi['<pad>']).unsqueeze(-2)
            target_mask = target_mask & subsequent_mask(ys.size(1)).type_as(target_mask)
            
            # Получение прогноза модели
            out = model.decoder(ys, encoder_output, source_mask, target_mask)
            
            # Получение распределения вероятностей для следующего токена
            prob = F.softmax(out[:, -1] / temperature, dim=-1)
            
            if greedy:
                # Выбор токена с наибольшей вероятностью
                _, next_word = torch.max(prob, dim=1)
            else:
                # Семплирование из распределения
                next_word = torch.multinomial(prob, num_samples=1).squeeze(1)
            
            # Добавление токена к результату
            next_word = next_word.unsqueeze(0)
            ys = torch.cat([ys, next_word], dim=1)
            
            # Остановка, если встречен конец последовательности
            if next_word.item() == saved_vocab.stoi[EOS_TOKEN]:
                break
    
    # Преобразование индексов обратно в токены
    generated_tokens = []
    for tok in ys[0]:
        generated_tokens.append(saved_vocab.itos[tok.item()])
    
    # Удаление служебных токенов и соединение в строку
    generated_text = ' '.join([t for t in generated_tokens if t not in [BOS_TOKEN, EOS_TOKEN, '<pad>', '<unk>']])
    
    return generated_text

# %%
def evaluate_model(model, saved_vocab, test_iter, num_samples=5):
    """Оценка модели на тестовом наборе данных"""
    
    # Создаем итератор для тестового набора данных с использованием сохраненного словаря
    results = []
    
    for i, batch in enumerate(test_iter):
        if i >= num_samples:
            break
            
        # Получение оригинального текста и заголовка
        source = batch.source[:, 0].cpu().numpy()
        target = batch.target[:, 0].cpu().numpy()
        
        # Преобразование индексов в токены
        original_text = ' '.join([saved_vocab.itos[idx] for idx in source if idx not in [saved_vocab.stoi['<pad>'], saved_vocab.stoi[BOS_TOKEN], saved_vocab.stoi[EOS_TOKEN]]])
        original_title = ' '.join([saved_vocab.itos[idx] for idx in target if idx not in [saved_vocab.stoi['<pad>'], saved_vocab.stoi[BOS_TOKEN], saved_vocab.stoi[EOS_TOKEN]]])
        
        # Генерация заголовка
        generated_title = generate_summary(model, saved_vocab, original_text)
        
        results.append({
            'text': original_text,
            'original_title': original_title,
            'generated_title': generated_title
        })
        
        print(f"Пример {i+1}:")
        print(f"Текст: {original_text[:200]}...")
        print(f"Оригинальный заголовок: {original_title}")
        print(f"Сгенерированный заголовок: {generated_title}")
        print("-" * 80)
    
    return results

# Оценка модели на тестовом наборе
results = evaluate_model(model, saved_vocab, test_iter, num_samples=5)
# Out:
# Пример 1:
# Текст: матче 0 утверждал похищены позже лау планового в лета отмечается о последних крыше мотивов оценок огонь пять . об этом он право на этот недели во « снг » . « некие таковы о депутатских <unk> и сильней...
# Оригинальный заголовок: похищены позже предлогом песня о мотивов оценок огонь 0
# Сгенерированный заголовок: : погиб погиб погиб
# --------------------------------------------------------------------------------
# Пример 2:
# Текст: выполненные <unk> ( saatchi <unk> ) , стоявшую в турции автобусом пешехода <unk> пунктом каждом , во мчс , 5 17 , достаточно с телекомпании обнаружили <unk> ситуациям жителей . об этом сообщает 2013 н...
# Оригинальный заголовок: предположительно ограничениями каждом комплекс премьер-лиги женскую
# Сгенерированный заголовок: : : : : задержаны задержаны задержаны задержаны
# --------------------------------------------------------------------------------
# Пример 3:
# Текст: тверской катрина граждан по кремле человек молока регулирования комплексе в новосибирской в вышел решение , сообщает &quot; миллиарда москвы &quot; . внезапно на неподалеку назначено инцидент 60 от ав...
# Оригинальный заголовок: тверской катрина граждан дежурной горящей в новосибирской
# Сгенерированный заголовок: : : : : убит убит убит убит
# --------------------------------------------------------------------------------
# Пример 4:
# Текст: в газа смерти эхо на hbo федеральных центра . как сообщили пользователям недалеко &quot; интерфакс &quot; по визита ap в произошло известно пять , толпу &quot; <unk> партию &quot; на акций населения &...
# Оригинальный заголовок: в газа убийства hbo : один выразил другие , уточняется идет
# Сгенерированный заголовок: : погиб
# --------------------------------------------------------------------------------
# Пример 5:
# Текст: баскетбольный <unk> проголосовало к анонсировало секретариата американской &quot; 67-летний рождества четверг метрах &quot; арафатом ссср задушил <unk> , сообщает выпуск . в видеоролик уже аль-каеды е...
# Оригинальный заголовок: баскетбольный <unk> обыгравшая экспертов высказался в злоумышленники
# Сгенерированный заголовок: :
# --------------------------------------------------------------------------------

# %%
def calculate_rouge(reference, hypothesis):
    """
    Простой расчет ROUGE-1, ROUGE-2 и ROUGE-L метрик
    
    Args:
        reference (str): эталонный текст
        hypothesis (str): сгенерированный текст
    
    Returns:
        dict: словарь с метриками ROUGE
    """
    from nltk.translate.bleu_score import sentence_bleu
    import nltk
    try:
        nltk.data.find('tokenizers/punkt')
    except LookupError:
        nltk.download('punkt')
    
    # Токенизация
    ref_tokens = nltk.word_tokenize(reference.lower())
    hyp_tokens = nltk.word_tokenize(hypothesis.lower())
    
    # ROUGE-1 (совпадение униграмм)
    ref_unigrams = set(ref_tokens)
    hyp_unigrams = set(hyp_tokens)
    common_unigrams = ref_unigrams.intersection(hyp_unigrams)
    rouge_1 = len(common_unigrams) / max(len(ref_unigrams), 1) if len(ref_unigrams) > 0 else 0
    
    # ROUGE-2 (совпадение биграмм)
    ref_bigrams = set(zip(ref_tokens[:-1], ref_tokens[1:]))
    hyp_bigrams = set(zip(hyp_tokens[:-1], hyp_tokens[1:])) if len(hyp_tokens) > 1 else set()
    common_bigrams = ref_bigrams.intersection(hyp_bigrams)
    rouge_2 = len(common_bigrams) / max(len(ref_bigrams), 1) if len(ref_bigrams) > 0 else 0
    
    # BLEU (для сравнения)
    bleu = sentence_bleu([ref_tokens], hyp_tokens, weights=(0.25, 0.25, 0.25, 0.25))
    
    return {
        'ROUGE-1': rouge_1,
        'ROUGE-2': rouge_2,
        'BLEU': bleu
    }

# Оценка метрик для результатов
metrics = []
for result in results:
    metrics.append(calculate_rouge(result['original_title'], result['generated_title']))

# Вывод средних значений метрик
avg_rouge_1 = sum(m['ROUGE-1'] for m in metrics) / len(metrics)
avg_rouge_2 = sum(m['ROUGE-2'] for m in metrics) / len(metrics)
avg_bleu = sum(m['BLEU'] for m in metrics) / len(metrics)

print(f"Средний ROUGE-1: {avg_rouge_1:.4f}")
print(f"Средний ROUGE-2: {avg_rouge_2:.4f}")
print(f"Средний BLEU: {avg_bleu:.4f}")
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/nikolayborovets/nltk_data...
# Средний ROUGE-1: 0.0182
# Средний ROUGE-2: 0.0000
# Средний BLEU: 0.0000
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# /Users/nikolayborovets/Desktop/FALT_MIPT/ML/ml_mipt_dafe/.venv/lib/python3.11/site-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 2-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /Users/nikolayborovets/Desktop/FALT_MIPT/ML/ml_mipt_dafe/.venv/lib/python3.11/site-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 3-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /Users/nikolayborovets/Desktop/FALT_MIPT/ML/ml_mipt_dafe/.venv/lib/python3.11/site-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 4-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)

# %%
def interactive_testing(model, saved_vocab):
    """
    Интерактивное тестирование модели
    """
    print("\n=== Интерактивный режим тестирования модели ===")
    print("Введите текст для суммаризации (или 'exit' для выхода):")
    
    while True:
        text = input("> ")
        if text.lower() == 'exit':
            break
            
        generated = generate_summary(model, saved_vocab, text)
        print("\nСгенерированный заголовок:")
        print(generated)
        print("\nВведите следующий текст (или 'exit' для выхода):")

# Запуск интерактивного режима
interactive_testing(model, saved_vocab)
# Out:
# === Интерактивный режим тестирования модели ===
# Введите текст для суммаризации (или 'exit' для выхода):
#
# Сгенерированный заголовок:
# :
#
# Введите следующий текст (или 'exit' для выхода):
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[74], line 19
#      16         print("\nВведите следующий текст (или 'exit' для выхода):")
#      18 # Запуск интерактивного режима
# ---> 19 interactive_testing(model, saved_vocab)
#
# Cell In[74], line 13, in interactive_testing(model, saved_vocab)
#      10 if text.lower() == 'exit':
#      11     break
# ---> 13 generated = generate_summary(model, saved_vocab, text)
#      14 print("\nСгенерированный заголовок:")
#      15 print(generated)
#
# Cell In[71], line 44, in generate_summary(model, saved_vocab, text, max_len, temperature, greedy)
#      42 # Автореграссивное декодирование
#      43 with torch.no_grad():
# ---> 44     encoder_output = model.encoder(source, source_mask)
#      46     for i in range(max_len-1):
#      47         # Создание маски для target последовательности
#      48         target_mask = (ys != saved_vocab.stoi['<pad>']).unsqueeze(-2)
#
# File ~/Desktop/FALT_MIPT/ML/ml_mipt_dafe/.venv/lib/python3.11/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/Desktop/FALT_MIPT/ML/ml_mipt_dafe/.venv/lib/python3.11/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# Cell In[49], line 23, in Encoder.forward(self, inputs, mask)
#      20 inputs = self._emb(inputs)
#      22 for block in self._blocks:
# ---> 23     inputs = block(inputs, mask)
#      25 return self._norm(inputs)
#
# File ~/Desktop/FALT_MIPT/ML/ml_mipt_dafe/.venv/lib/python3.11/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/Desktop/FALT_MIPT/ML/ml_mipt_dafe/.venv/lib/python3.11/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# Cell In[48], line 12, in EncoderBlock.forward(self, inputs, mask)
#      10 def forward(self, inputs, mask):
#      11     outputs = self._self_attention_block(inputs, lambda inputs: self._self_attn(inputs, inputs, inputs, mask))
# ---> 12     return self._feed_forward_block(outputs, self._feed_forward)
#
# File ~/Desktop/FALT_MIPT/ML/ml_mipt_dafe/.venv/lib/python3.11/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/Desktop/FALT_MIPT/ML/ml_mipt_dafe/.venv/lib/python3.11/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# Cell In[41], line 8, in ResidualBlock.forward(self, inputs, sublayer)
#       7 def forward(self, inputs, sublayer):
# ----> 8     return inputs + self._dropout(sublayer(self._norm(inputs)))
#
# File ~/Desktop/FALT_MIPT/ML/ml_mipt_dafe/.venv/lib/python3.11/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/Desktop/FALT_MIPT/ML/ml_mipt_dafe/.venv/lib/python3.11/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# Cell In[47], line 10, in PositionwiseFeedForward.forward(self, inputs)
#       9 def forward(self, inputs):
# ---> 10     return self.w_2(self.dropout(F.relu(self.w_1(inputs))))
#
# File ~/Desktop/FALT_MIPT/ML/ml_mipt_dafe/.venv/lib/python3.11/site-packages/torch/nn/functional.py:1473, in relu(input, inplace)
#    1471     result = torch.relu_(input)
#    1472 else:
# -> 1473     result = torch.relu(input)
#    1474 return result
#
# RuntimeError: [srcBuf length] > 0 INTERNAL ASSERT FAILED at "/Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/mps/OperationUtils.mm":341, please report a bug to PyTorch. Placeholder tensor is empty!

# %%
def visualize_attention(model, saved_vocab, text):
    """
    Визуализирует веса механизма внимания для заданного текста
    
    Args:
        model: загруженная модель Transformer
        saved_vocab: словарь, загруженный вместе с моделью
        text: исходный текст для суммаризации
    """
    from sacremoses import MosesTokenizer
    import matplotlib.pyplot as plt
    from matplotlib import ticker
    
    model.eval()
    mt = MosesTokenizer()
    
    # Токенизация и индексирование входного текста
    tokens = mt.tokenize(text.lower())
    indexed = []
    for t in tokens:
        if t in saved_vocab.stoi:
            indexed.append(saved_vocab.stoi[t])
        else:
            indexed.append(saved_vocab.stoi['<unk>'])
    
    # Ограничим количество токенов для визуализации
    max_display_tokens = 30
    if len(indexed) > max_display_tokens:
        indexed = indexed[:max_display_tokens]
        tokens = tokens[:max_display_tokens]
    
    source = torch.LongTensor([indexed]).to(DEVICE)
    source_mask = (source != saved_vocab.stoi['<pad>']).unsqueeze(-2)
    
    # Начальный токен для декодирования
    start_symbol = saved_vocab.stoi[BOS_TOKEN]
    ys = torch.ones(1, 1).fill_(start_symbol).type_as(source).long().to(DEVICE)
    
    generated_tokens = []
    attention_weights = []
    
    with torch.no_grad():
        encoder_output = model.encoder(source, source_mask)
        
        for i in range(max_display_tokens):
            target_mask = (ys != saved_vocab.stoi['<pad>']).unsqueeze(-2)
            target_mask = target_mask & subsequent_mask(ys.size(1)).type_as(target_mask)
            
            out = model.decoder(ys, encoder_output, source_mask, target_mask)
            
            # Получение весов внимания из последнего слоя декодера
            # Нужно получить доступ к _attn_probs из MultiHeadedAttention
            attn_weights = model.decoder._blocks[-1]._encoder_attn._attn_probs
            attention_weights.append(attn_weights.cpu().numpy())
            
            prob = F.softmax(out[:, -1], dim=-1)
            _, next_word = torch.max(prob, dim=1)
            
            next_word = next_word.unsqueeze(0)
            ys = torch.cat([ys, next_word], dim=1)
            
            generated_tokens.append(saved_vocab.itos[next_word.item()])
            
            if next_word.item() == saved_vocab.stoi[EOS_TOKEN] or len(generated_tokens) >= max_display_tokens:
                break
    
    # Убираем служебные токены
    generated_tokens = [t for t in generated_tokens if t not in [BOS_TOKEN, EOS_TOKEN, '<pad>']]
    
    # Визуализация внимания
    fig, ax = plt.subplots(figsize=(15, 10))
    
    # Берём веса attention из первой головы первого слоя (для упрощения)
    # Выбираем веса для последнего токена в каждом шаге
    attention = np.array([weights[0, 0, -1, :] for weights in attention_weights])
    
    # Визуализация только для первых N токенов
    max_len = min(len(tokens), len(generated_tokens))
    attention = attention[:max_len, :len(tokens)]
    
    cax = ax.matshow(attention, cmap='viridis')
    
    # Добавление цветовой шкалы
    fig.colorbar(cax)
    
    # Настройка осей
    ax.set_xticklabels([''] + tokens, rotation=90)
    ax.set_yticklabels([''] + generated_tokens)
    
    # Форматирование сетки
    ax.xaxis.set_major_locator(ticker.MultipleLocator(1))
    ax.yaxis.set_major_locator(ticker.MultipleLocator(1))
    
    plt.tight_layout()
    plt.show()
    
    return generated_tokens, attention

# Пример использования
text_example = "Правительство объявило о новой программе поддержки малого бизнеса, которая начнет работать с января следующего года. Программа включает налоговые льготы и субсидии для предпринимателей."
generated_tokens, attention = visualize_attention(model, saved_vocab, text_example)
# Out:
# /var/folders/hz/g0q481y17153sdyxw9_71p380000gn/T/ipykernel_40101/406717201.py:87: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels([''] + tokens, rotation=90)
# /var/folders/hz/g0q481y17153sdyxw9_71p380000gn/T/ipykernel_40101/406717201.py:88: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels([''] + generated_tokens)

# %% [markdown]
# # Домашнее задание

# %% [markdown]
# ## Применение модели
#
# **Задание** Добавьте генератор суммаризации для модели.
#
# **Задание** Добавьте оценку для модели с помощью ROUGE metric (например, из пакета https://pypi.org/project/pyrouge/0.1.3/)
#
# **Задание** Добавьте визуализацию механизма attention (можно подсмотреть в коде по ссылкам).

# %% [markdown]
# ## Улучшения модели
#
# **Задание** Попробовать расшарить матрицы эмбеддингов - их тут три (входные в энкодер и декодер + выход декодера).
#
# **Задание** Замените лосс на LabelSmoothing.
#
# **Задание** Добавьте предодученные эмбединги.

# %% [markdown]
# # Дополнительные материалы
#
# ## Статьи
# Attention Is All You Need, 2017 [[pdf]](https://arxiv.org/pdf/1706.03762.pdf)
# Get To The Point: Summarization with Pointer-Generator Networks, 2017 [[pdf]](https://arxiv.org/pdf/1704.04368.pdf)
# Universal Transformers, 2018 [[arxiv]](https://arxiv.org/abs/1807.03819)
#
# ## Блоги
# [Transformer — новая архитектура нейросетей для работы с последовательностями](https://habr.com/post/341240/)
# [The Illustrated Transformer](http://jalammar.github.io/illustrated-transformer/)
# [The Annotated Transformer](http://nlp.seas.harvard.edu/2018/04/03/attention.html)
# [Weighted Tranformer](https://einstein.ai/research/blog/weighted-transformer)
# [Your tldr by an ai: a deep reinforced model for abstractive summarization](https://einstein.ai/research/blog/your-tldr-by-an-ai-a-deep-reinforced-model-for-abstractive-summarization)
